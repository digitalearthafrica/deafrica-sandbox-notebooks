# %% [markdown]
# # Harmonising Landsat 7 & 8
#
# * **Products used:**

# %% [raw]
# **Keywords**: :index:`data used; landsat 8`, :index:`analysis; change detection`, :index:`band index; NDVI`, :index:`band index; EVI`, :index:`forestry`

# %% [markdown]
# ### Background
#
# ### Description
#
#
# ***

# %% [markdown]
# ## Getting started

# %% [markdown]
# ### Load packages
# Load key Python packages and any supporting functions for the analysis.

# %%
import datacube
import datacube.utils.rio
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

import xarray as xr


from deafrica_tools.datahandling import load_ard
from deafrica_tools.plotting import display_map, rgb
from deafrica_tools.bandindices import calculate_indices
from deafrica_tools.dask import create_local_dask_cluster

#This will speed up loading data
datacube.utils.rio.set_default_rio_config(aws='auto', cloud_defaults=True)
# Out:
# /env/lib/python3.8/site-packages/datacube/storage/masking.py:7: DeprecationWarning: datacube.storage.masking has moved to datacube.utils.masking
#   warnings.warn("datacube.storage.masking has moved to datacube.utils.masking",

# %%
create_local_dask_cluster()
# Out:
# <Client: 'tcp://127.0.0.1:34575' processes=1 threads=4, memory=28.14 GB>

# %% [markdown]
# ### Connect to the datacube
# Activate the datacube database, which provides functionality for loading and displaying stored Earth observation data.

# %%
dc = datacube.Datacube(app="HLS")

# %% [markdown]
# ### Analysis parameters

# %%
# Define the area of interest
#Northern Nigeria
# latitude = 12.24142
# longitude = 9.33816

#Southern Nigeia
# latitude = 8.05477
# longitude = 11.01148

# #Northern Ghana
# latitude = 10.15034
# longitude = 0.34555

#Southen Ghana
# latitude = 6.05653
# longitude = 0.50653

#western ivory coast
# latitude = 9.52254
# longitude = -5.57921

# Guinea Part
# latitude = 10.75481
# longitude = -11.05431

#Guinea Southern 
# latitude = 9.45168
# longitude = -13.46149

# Ethiopia
# latitude = 9.70906
# longitude = 38.62793

#Egypt
latitude= 29.2401
longitude=30.7371

# #kenya
# latitude = -4.39023
# longitude = 33.09082

buffer = 0.01

crop_mask = 'crop_mask_northern'

# Combine central lat,lon with buffer to get area of interest
lat_range = (latitude-buffer, latitude+buffer)
lon_range = (longitude-buffer, longitude+buffer)

# Set the range of dates for the complete sample
time = ('2019')

dask_chunks = dict(x=1000, y=1000)

# %% [markdown]
# ## View the selected location
# The next cell will display the selected area on an interactive map.
# The red border represents the area of interest of the study.
# Zoom in and out to get a better understanding of the area of interest.
# Clicking anywhere on the map will reveal the latitude and longitude coordinates of the clicked point.

# %%
display_map(x=lon_range, y=lat_range)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Load and view Landsat data

# %%
#Create a query object
query = {
    'x': lon_range,
    'y': lat_range,
    'time': time,
    'measurements': ['red','nir'],
    'resolution': (-30, 30),
    'group_by': 'solar_day',
    'output_crs': 'EPSG:6933'
}

# %%
# load cloud-masked ls8 using load_ard
ds_ls8 = load_ard(dc=dc,
              products=['ls8_sr'],
              min_gooddata=0.95,
              mask_filters=(['opening',5], ['dilation',5]),
              dask_chunks=dask_chunks,
              **query,
             )
# Out:
# /home/jovyan/Tools/deafrica_tools/datahandling.py:260: UserWarning: Setting 'min_gooddata' percentage to > 0.0 will cause dask arrays to compute when loading pixel-quality data to calculate 'good pixel' percentage. This can slow the return of your dataset.
#   warnings.warn(
# Using pixel quality parameters for USGS Collection 2
# Finding datasets
#     ls8_sr
# Counting good quality pixels for each time step
# CPLReleaseMutex: Error = 1 (Operation not permitted)
# Filtering to 36 out of 45 time steps with at least 95.0% good quality pixels
# Applying morphological filters to pq mask (['opening', 5], ['dilation', 5])
# Applying pixel quality/cloud mask
# Re-scaling Landsat C2 data
# Returning 36 time steps as a dask array

# %%
# load cloud-masked fractional cover using load_ard
ds_ls7 = load_ard(dc=dc,
              products=['ls7_sr'],
              like=ds_ls8.geobox,
              time=time,
              measurements=['red','nir'],
              min_gooddata=0.95,
              mask_filters=(['opening',5], ['dilation',5]),
              dask_chunks=dask_chunks
             )
# Out:
# Using pixel quality parameters for USGS Collection 2
# Finding datasets
#     ls7_sr
# Counting good quality pixels for each time step
# /home/jovyan/Tools/deafrica_tools/datahandling.py:260: UserWarning: Setting 'min_gooddata' percentage to > 0.0 will cause dask arrays to compute when loading pixel-quality data to calculate 'good pixel' percentage. This can slow the return of your dataset.
#   warnings.warn(
# Filtering to 33 out of 43 time steps with at least 95.0% good quality pixels
# Applying morphological filters to pq mask (['opening', 5], ['dilation', 5])
# Applying pixel quality/cloud mask
# Re-scaling Landsat C2 data
# Returning 33 time steps as a dask array

# %%
cm = dc.load(product=crop_mask,
            time=('2019'),
            measurements='mask',
            resampling='nearest', 
            like=ds_ls8.geobox).mask.squeeze()

cm.plot.imshow(add_colorbar=False, figsize=(5,5))
plt.title('Cropland Extent');

# %% [markdown]
# ### Mask non-croplands

# %%
ds_ls8 = ds_ls8.where(cm, np.nan)
ds_ls7 = ds_ls7.where(cm, np.nan)

# %% [markdown]
# ## Match Landsat 7 & 8 acquistion times
#
# Tolerance of 3 days

# %%
ds_ls7 = ds_ls7.reindex(time=ds_ls8.time, method='nearest', tolerance='3D')

# %%
ds_ls8 = calculate_indices(ds_ls8, 'NDVI', collection='c2', drop=False)
ds_ls7 = calculate_indices(ds_ls7, 'NDVI', collection='s2', drop=False)

# %% [markdown]
# ### Harmonize Landsat 8 with landsat 7 using Chastain et. al 2019
#
# https://www.sciencedirect.com/science/article/pii/S0034425718305212?via%3Dihub

# %%
# multiplying the red band with slope and adding to intercept
slope = 1.0199
intercept = -0.0021
ds_ls7['red_chastain']  = (ds_ls7['red'] * slope) + intercept

# %%
# multiplying the nir band with slope and adding to intercept
slope = 1.1406
intercept = -0.0163
ds_ls7['nir_chastain']  = (ds_ls7['nir'] * slope) + intercept

# %% [markdown]
# #### Recalcuate NDVI

# %%
ds_ls7['ndvi_chastain'] = (
    (ds_ls7['nir_chastain']-ds_ls7['red_chastain'])
    /
    (ds_ls7['nir_chastain']+ds_ls7['red_chastain'])
)

# %% [markdown]
# ### Reduce to 1D for plotting

# %%
ndvi_ls8 = ds_ls8.NDVI.mean(dim=['x','y']).compute()
ndvi_ls7 = ds_ls7.NDVI.mean(dim=['x','y']).compute()
ndvi_ls7_chastain = ds_ls7.ndvi_chastain.mean(dim=['x','y']).compute()

# %% [markdown]
# ### time series plot

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7_chastain.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()

# %% [markdown]
# ### Harmonize Landsat 8 with landsat 7 using Aus Coeffiecients
# https://www.mdpi.com/2072-4292/6/9/7952/htm

# %%
# multiplying the red band with slope and adding to intercept
slope = 1.00446
intercept = 0.00274
ds_ls8['red_aus']  = (ds_ls8['red'] * slope) + intercept

# %%
# multiplying the nir band with slope and adding to intercept
slope = 0.98906
intercept =0.00004
ds_ls8['nir_aus']  = (ds_ls8['nir'] * slope) + intercept

# %%
ds_ls8['ndvi_aus'] = (
    (ds_ls8['nir_aus']-ds_ls8['red_aus'])
    /
    (ds_ls8['nir_aus']+ds_ls8['red_aus'])
)

# %%
ndvi_ls8_aus = ds_ls8.ndvi_aus.mean(dim=['x','y']).compute()

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ls8_aus.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()

# %% [markdown]
# ### Harmonize Landsat 8 with landsat 7 using Roy Surface Reflectance NDVI Coeffiecients
#
# https://www.sciencedirect.com/science/article/pii/S0034425715302455

# %% [markdown]
# RMA regression coefficients
#
# OLI = 0.0149 + 1.0035 ETM

# %%
ndvi_ls7_adj = 0.0149 + (1.0035 * ds_ls7.NDVI)

# %%
ndvi_ls7_adj = ndvi_ls7_adj.mean(dim=['x','y']).compute()

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7_adj.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()

# %% [markdown]
# OLS transformation functions
#
# OLI = 0.0235 + 0.9723 ETM +

# %%
ndvi_ls7_adj_ = 0.0235 + (0.9723 * ds_ls7.NDVI)

# %%
ndvi_ls7_adj_ = ndvi_ls7_adj_.mean(dim=['x','y']).compute()

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7_adj_.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()

# %% [markdown]
# OLS transformation functions
#
# ETM + = 0.0029 + 0.9589 OLI

# %%
ndvi_ls8_adj_ = 0.0029 + (0.9589 * ds_ls8.NDVI)

# %%
ndvi_ls8_adj_ = ndvi_ls8_adj_.mean(dim=['x','y']).compute()

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ls8_adj_.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()

# %% [markdown]
# var l8tol7 = l8img.subtract(intercept).divide(slope)

# %%
# multiplying the red band with slope and adding to intercept
slope =  0.9825
intercept = -0.0022
ds_ls8['red_roy']  = (ds_ls8['red']  - intercept ) / slope

# %%
slope =  1.0073
intercept =  -0.0021
ds_ls8['nir_roy']  = (ds_ls8['nir']  - intercept ) / slope

# %%
ds_ls8['ndvi_roy'] = (
    (ds_ls8['nir_roy']-ds_ls8['red_roy'])
    /
    (ds_ls8['nir_roy']+ds_ls8['red_roy'])
)

# %%
ndvi_ds_ls8 = ds_ls8.ndvi_roy.mean(dim=['x','y']).compute()

# %%
plt.figure(figsize=(18, 4))
ndvi_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('Before Band Adjustment')
plt.grid()

plt.figure(figsize=(18, 4))
ndvi_ds_ls8.plot(marker='.', lw=0, color='red', ms=10, label='Landsat 8')
ndvi_ls7.plot(marker='*', lw=0, ms=10, color='green', label='Landsat 7')
plt.legend()
plt.title('After Band Adjustment')

plt.grid()
plt.show()
