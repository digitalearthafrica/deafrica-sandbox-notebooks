# %% [markdown]
# <div id="page-top" style="
#     max-width:1100px;
#     margin:18px auto 0;
#     font-family:Arial, Helvetica, sans-serif;
# ">
#   <img
#       src="Supplementary_data/Github_banner.jpg"
#       alt="Digital Earth Africa"
#       style="
#           display:block;
#           width:100%;
#           border-radius:14px 14px 0 0;
#           box-shadow:0 4px 16px rgba(15,23,42,0.12);
#       "
#   >
#
#   <div style="
#       padding:24px 28px;
#       color:#ffffff;
#       background:linear-gradient(135deg,#0b1026 0%,#172554 58%,#0f766e 100%);
#       border-radius:0 0 14px 14px;
#       box-shadow:0 5px 18px rgba(15,23,42,0.15);
#   ">
#     <div style="
#         color:#fcd34d;
#         font-size:12px;
#         font-weight:700;
#         letter-spacing:1.4px;
#         text-transform:uppercase;
#     ">Digital Earth Africa Sandbox</div>
#     <h1 style="
#         margin:6px 0 8px;
#         color:#ffffff;
#         font-size:31px;
#         font-weight:750;
#         line-height:1.25;
#     ">Thematic Applications and Tools</h1>
#     <p style="
#         max-width:830px;
#         margin:0;
#         color:#e2e8f0;
#         font-size:15px;
#         line-height:1.65;
#     ">
#       Find notebooks by topic and move directly to the analysis that matches
#       your area of interest. Each theme includes ready-to-use datasets,
#       real-world examples, and practical workflows.
#     </p>
#     <div style="display:flex; flex-wrap:wrap; gap:9px; margin-top:18px;">
#       <a href="DEAfricaLandingPage.ipynb" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#0b1026;
#           background-color:#fcd34d;
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">← Landing Page</a>
#       <a href="#theme-directory" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:rgba(255,255,255,0.13);
#           border:1px solid rgba(255,255,255,0.25);
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Browse Themes</a>
#       <a href="#resources" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:rgba(255,255,255,0.13);
#           border:1px solid rgba(255,255,255,0.25);
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Resources</a>
#       <a href="#support" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:rgba(255,255,255,0.13);
#           border:1px solid rgba(255,255,255,0.25);
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Support</a>
#       <a href="DEAfricaInfo.ipynb" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:#2563eb;
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Tech Alerts</a>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div id="theme-directory" style="
#     box-sizing: border-box;
#     max-width: 1100px;
#     margin: 22px auto 28px;
#     padding: 18px 20px;
#     font-family: Arial, Helvetica, sans-serif;
#     color: #1f2937;
#     background-color: #ffffff;
#     border: 1px solid #dbe2ea;
#     border-radius: 10px;
#     box-shadow: 0 3px 12px rgba(15, 23, 42, 0.06);
# ">
#   <div style="
#       display: flex;
#       flex-wrap: wrap;
#       align-items: center;
#       justify-content: center;
#       gap: 8px;
#   ">
#     <span style="
#         margin-right: 4px;
#         color: #64748b;
#         font-size: 12px;
#         font-weight: 700;
#         letter-spacing: 0.8px;
#         text-transform: uppercase;
#     ">
#       Browse themes
#     </span>
#     <a href="#agriculture-vegetation" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #166534;
#         background-color: #f0fdf4;
#         border: 1px solid #bbf7d0;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Agriculture &amp; Vegetation</a>
#     <a href="#coastal" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #0369a1;
#         background-color: #f0f9ff;
#         border: 1px solid #bae6fd;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Coastal</a>
#     <a href="#elevation-topography" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #57534e;
#         background-color: #fafaf9;
#         border: 1px solid #d6d3d1;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Elevation &amp; Topography</a>
#     <a href="#land-cover" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #92400e;
#         background-color: #fffbeb;
#         border: 1px solid #fde68a;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Land Cover</a>
#     <a href="#machine-learning" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #6d28d9;
#         background-color: #f5f3ff;
#         border: 1px solid #ddd6fe;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Machine Learning</a>
#     <a href="#meteorology" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #0e7490;
#         background-color: #ecfeff;
#         border: 1px solid #a5f3fc;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Meteorology</a>
#     <a href="#radar-backscatter" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #7e22ce;
#         background-color: #faf5ff;
#         border: 1px solid #e9d5ff;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Radar Backscatter</a>
#     <a href="#satellite-images" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #1d4ed8;
#         background-color: #eff6ff;
#         border: 1px solid #bfdbfe;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Satellite Images</a>
#     <a href="#soil" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #9a3412;
#         background-color: #fff7ed;
#         border: 1px solid #fed7aa;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Soil</a>
#     <a href="#surface-water" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #075985;
#         background-color: #f0f9ff;
#         border: 1px solid #bae6fd;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Surface Water</a>
#     <a href="#urban" style="
#         display: inline-block;
#         padding: 8px 12px;
#         color: #92400e;
#         background-color: #fffbeb;
#         border: 1px solid #fde68a;
#         border-radius: 999px;
#         font-size: 13px;
#         font-weight: 700;
#         text-decoration: none;
#     ">Urban</a>
#   </div>
#
#   <p style="
#       margin: 13px 0 0;
#       color: #64748b;
#       font-size: 13px;
#       line-height: 1.55;
#       text-align: center;
#   ">
#     Select a theme to jump directly to its notebook collection.
#   </p>
# </div>

# %% [markdown]
# <div id="agriculture-vegetation" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #bbf7d0;
#     border-top:6px solid #15803d;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#f0fdf4 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#15803d;
#           background-color:#ffffff;
#           border:1px solid #bbf7d0;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">🌱</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#15803d;
#             font-size:23px;
#             line-height:1.3;
#         ">Agriculture and Vegetation</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Monitor crops, forests, mangroves, vegetation condition, productivity, and seasonal change.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#15803d;
#         background-color:#ffffff;
#         border:1px solid #bbf7d0;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">20 notebooks</span>
#   </div>
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Datasets/Cropland_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Cropland Extent</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Crop_health.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Crop Health</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Crop_health_EVI.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Crop Health EVI</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Forecasting_vegetation_condition.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forecasting Vegetation Condition</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Forest_monitoring.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forest Monitoring</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Fractional_Cover.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Fractional Cover</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Global_Mangrove_Watch.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Global Mangrove Watch</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Inspecting_WaPOR_through_time.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Inspecting WaPOR through time</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Mangrove_analysis.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mangrove Analysis</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="SDGs/Mountain_Green_Cover_Index/MGCI.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mountain Green Cover Index</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/NDVI_animations.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Animations</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/NDVI_Anomaly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Anomaly</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/NDVI_Climatology.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Climatology</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Phenology_optical.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Phenology Optical</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Phenology_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Phenology Radar</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Vegetation_anomalies_monthly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Anomalies Monthly</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Vegetation_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Change Detection</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Lake_baringo_grazing/Vegetation_phenology_1D.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology 1D</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Lake_baringo_grazing/Vegetation_phenology_perpixel.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology Per Pixel</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/WaPOR.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>WaPOR Data</span>
#   <span style="color:#15803d; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="coastal" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #bae6fd;
#     border-top:6px solid #0284c7;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#f0f9ff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#0284c7;
#           background-color:#ffffff;
#           border:1px solid #bae6fd;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">🌊</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#0284c7;
#             font-size:23px;
#             line-height:1.3;
#         ">Coastal</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Explore coastlines, erosion, intertidal elevation, and marine-debris applications.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#0284c7;
#         background-color:#ffffff;
#         border:1px solid #bae6fd;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">5 notebooks</span>
#   </div>
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Coastal_erosion.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Coastal Erosion</span>
#   <span style="color:#0284c7; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Floating_marine_debris.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Floating Marine Debris</span>
#   <span style="color:#0284c7; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Intertidal_elevation.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Intertidal Elevation</span>
#   <span style="color:#0284c7; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Intertidal_elevation_S2.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Intertidal Elevation S2</span>
#   <span style="color:#0284c7; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Coastlines.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Coastlines</span>
#   <span style="color:#0284c7; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="elevation-topography" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #d6d3d1;
#     border-top:6px solid #78716c;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#fafaf9 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#78716c;
#           background-color:#ffffff;
#           border:1px solid #d6d3d1;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">⛰</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#78716c;
#             font-size:23px;
#             line-height:1.3;
#         ">Elevation and topography</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Access elevation and terrain datasets for landscape and topographic analysis.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#78716c;
#         background-color:#ffffff;
#         border:1px solid #d6d3d1;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">1 notebook</span>
#   </div>
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Datasets/Digital_Elevation_Models.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Digital Elevation Models</span>
#   <span style="color:#78716c; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="land-cover" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #fde68a;
#     border-top:6px solid #a16207;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#fffbeb 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#a16207;
#           background-color:#ffffff;
#           border:1px solid #fde68a;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">🗺</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#a16207;
#             font-size:23px;
#             line-height:1.3;
#         ">Land Cover</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Map land cover, fire impacts, mining activity, and land-use change.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#a16207;
#         background-color:#ffffff;
#         border:1px solid #fde68a;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">5 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Burnt_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Burnt Area Mapping</span>
#   <span style="color:#a16207; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Burnt_area_mapping_near_realtime.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Burnt Area Mapping Near Realtime</span>
#   <span style="color:#a16207; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine Learning With ODC</span>
#   <span style="color:#a16207; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Surface_mining_screening/Surface_mining_screening.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Surface Mining Screening</span>
#   <span style="color:#a16207; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Land_Use_Land_Cover_Maps.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Use Land Cover Maps</span>
#   <span style="color:#a16207; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="machine-learning" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #ddd6fe;
#     border-top:6px solid #7c3aed;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#f5f3ff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#7c3aed;
#           background-color:#ffffff;
#           border:1px solid #ddd6fe;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">◆</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#7c3aed;
#             font-size:23px;
#             line-height:1.3;
#         ">Machine Learning</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Build scalable classification workflows from training-data extraction to final mapping.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#7c3aed;
#         background-color:#ffffff;
#         border:1px solid #ddd6fe;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">6 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Scalable_machine_learning/1_Extract_training_data.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Extract Training Data</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Scalable_machine_learning/2_Inspect_training_data.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Inspect Training Data</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Scalable_machine_learning/3_Evaluate_optimize_fit_classifier.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Evaluate Optimize Fit Classifier</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Scalable_machine_learning/4_Classify_satellite_data.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Classify Satellite Data</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Scalable_machine_learning/5_Object-based_filtering.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Object-based Filtering</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine Learning With ODC</span>
#   <span style="color:#7c3aed; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="meteorology" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #a5f3fc;
#     border-top:6px solid #0891b2;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#ecfeff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#0891b2;
#           background-color:#ffffff;
#           border:1px solid #a5f3fc;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">☁</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#0891b2;
#             font-size:23px;
#             line-height:1.3;
#         ">Meteorology</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Analyse rainfall, temperature, climate anomalies, and ERA5 climate data.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#0891b2;
#         background-color:#ffffff;
#         border:1px solid #a5f3fc;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">5 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Animation_with_rainfall.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Animation with Rainfall</span>
#   <span style="color:#0891b2; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall Anomaly CHIRPS</span>
#   <span style="color:#0891b2; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Temperature_trends.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Temperature Trends</span>
#   <span style="color:#0891b2; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Climate_Data_ERA5_AWS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Climate Data ERA5</span>
#   <span style="color:#0891b2; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Rainfall_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall CHIRPS</span>
#   <span style="color:#0891b2; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="radar-backscatter" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #e9d5ff;
#     border-top:6px solid #9333ea;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#faf5ff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#9333ea;
#           background-color:#ffffff;
#           border:1px solid #e9d5ff;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">◉</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#9333ea;
#             font-size:23px;
#             line-height:1.3;
#         ">Radar Backscatter</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Use radar observations for water, urban, ship-detection, and backscatter applications.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#9333ea;
#         background-color:#ffffff;
#         border:1px solid #e9d5ff;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">5 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Radar_urban_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Radar Urban Area Mapping</span>
#   <span style="color:#9333ea; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Radar_water_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Radar Water Detection</span>
#   <span style="color:#9333ea; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Ship_detection_with_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Ship Detection with Radar</span>
#   <span style="color:#9333ea; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Sentinel_1.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Sentinel-1</span>
#   <span style="color:#9333ea; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/ALOS_PALSAR_Annual_Mosaic.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>ALOS PALSAR Annual Mosaic</span>
#   <span style="color:#9333ea; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="satellite-images" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #bfdbfe;
#     border-top:6px solid #2563eb;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#eff6ff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#2563eb;
#           background-color:#ffffff;
#           border:1px solid #bfdbfe;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">◈</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#2563eb;
#             font-size:23px;
#             line-height:1.3;
#         ">Satellite Images</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Load, visualise, export, composite, and animate optical satellite imagery.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#2563eb;
#         background-color:#ffffff;
#         border:1px solid #bfdbfe;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">9 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Datasets/GeoMAD.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>GeoMAD</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Rolling_GeoMAD.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rolling GeoMAD</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Landsat_Surface_Reflectance.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Landsat Surface Reflectance</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Landsat_Surface_Temperature.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Landsat Surface Temperature</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Sentinel_2.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Sentinel-2</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Planet_basemap.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Planet Basemap</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/OpenStreetMap.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Open Street Map</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Exporting_satellite_images.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Exporting Satellite Images</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Generating_satellite_animations.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Generating Satellite Animations</span>
#   <span style="color:#2563eb; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="soil" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #fed7aa;
#     border-top:6px solid #c2410c;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#fff7ed 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#c2410c;
#           background-color:#ffffff;
#           border:1px solid #fed7aa;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">▰</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#c2410c;
#             font-size:23px;
#             line-height:1.3;
#         ">Soil</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Explore soil moisture and continental-scale soil-property information.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#c2410c;
#         background-color:#ffffff;
#         border:1px solid #fed7aa;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">2 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Datasets/Soil_Moisture.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Soil Moisture</span>
#   <span style="color:#c2410c; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/iSDAsoil.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>iSDA Soil</span>
#   <span style="color:#c2410c; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="surface-water" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #bae6fd;
#     border-top:6px solid #0369a1;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#f0f9ff 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#0369a1;
#           background-color:#ffffff;
#           border:1px solid #bae6fd;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">💧</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#0369a1;
#             font-size:23px;
#             line-height:1.3;
#         ">Surface Water</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Monitor water extent, quality, wetlands, rainfall, discharge, and forecasting.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#0369a1;
#         background-color:#ffffff;
#         border:1px solid #bae6fd;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">19 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Chlorophyll_monitoring.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Chlorophyll Monitoring</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Water_extent_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Extent WOfS</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Water_extent_sentinel_2.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Extent Sentinel-2</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Water_quality_suspended_matter.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Quality Suspended Matter</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Wetland_turbidity.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Wetland Turbidity</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Wetlands_insight_tool.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Wetlands Insight Tool</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Lake_baringo_grazing/Water_Observations_from_Space.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Observations from Space</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Monitoring_water_extent/Monitoring_water_extent_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Water Extent WOfS</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Monitoring_water_extent/Monitoring_water_extent_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Water Extent Radar</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/0_Wetland_inundation_and_vegetation_dynamics.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Wetland Inundation and Vegetation Dynamics</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/1_Water_extent_longterm_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Extent Long-term WOfS</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/2_Water_extent_seasonal_MNDWI.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Extent Seasonal MNDWI</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/3_Historical_rainfall.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Historical Rainfall</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/4_Visualising_rainfall_discharge_water_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Visualising Rainfall Discharge Water Extent</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/5_Rainfall_discharge_modelling.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall Discharge Modelling</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/Okavango/6_Forecasting_water_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forecasting Water Extent</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Use_cases/surface_water_count/Vectorise_waterbodies.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vectorise Waterbodies</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Water_Observations_from_Space.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Observations from Space</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/Waterbodies.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Waterbodies</span>
#   <span style="color:#0369a1; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="urban" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:28px auto;
#     padding:0;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #fde68a;
#     border-top:6px solid #b45309;
#     border-radius:12px;
#     box-shadow:0 4px 14px rgba(15,23,42,0.07);
#     overflow:hidden;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:12px;
#       padding:20px 22px;
#       background:linear-gradient(180deg,#fffbeb 0%,#ffffff 100%);
#   ">
#     <div style="display:flex; align-items:flex-start; gap:13px;">
#       <div style="
#           flex:0 0 auto;
#           width:44px;
#           height:44px;
#           color:#b45309;
#           background-color:#ffffff;
#           border:1px solid #fde68a;
#           border-radius:10px;
#           text-align:center;
#           font-size:23px;
#           line-height:44px;
#       ">▦</div>
#       <div>
#         <h2 style="
#             margin:0;
#             color:#b45309;
#             font-size:23px;
#             line-height:1.3;
#         ">Urban</h2>
#         <p style="
#             max-width:760px;
#             margin:5px 0 0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Examine settlement growth, urban change, population, and built-up areas.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#b45309;
#         background-color:#ffffff;
#         border:1px solid #fde68a;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">5 notebooks</span>
#   </div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(275px,1fr));
#       gap:10px;
#       padding:0 22px 22px;
#   ">
#
# <a href="Real_world_examples/Urban_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban Change Detection</span>
#   <span style="color:#b45309; font-size:16px;">→</span>
# </a>
#
# <a href="Real_world_examples/Urban_index_comparison.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban Index Comparison</span>
#   <span style="color:#b45309; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/High_Resolution_Population_Density.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>High Resolution Population Density</span>
#   <span style="color:#b45309; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/World_Settlement_Footprint-Evolution.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>World Settlement Footprint-Evolution</span>
#   <span style="color:#b45309; font-size:16px;">→</span>
# </a>
#
# <a href="Datasets/World_Settlement_Footprint.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:48px;
#     padding:11px 13px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     font-size:14px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>World Settlement Footprint</span>
#   <span style="color:#b45309; font-size:16px;">→</span>
# </a>
#
#   </div>
#
#   <div style="padding:0 22px 19px;">
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
#   </div>
# </div>

# %% [markdown]
# <div id="resources" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:34px auto 14px;
#     padding:21px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#f8fafc;
#     border:1px solid #cbd5e1;
#     border-left:6px solid #7c3aed;
#     border-radius:10px;
# ">
#   <div style="color:#7c3aed; font-size:12px; font-weight:700; letter-spacing:1.1px; text-transform:uppercase;">
#     Resources and permissions
#   </div>
#   <h2 style="margin:5px 0 9px; color:#0b1026; font-size:24px;">
#     Documentation, Datasets, and Licence
#   </h2>
#
#   <div style="display:flex; flex-wrap:wrap; align-items:center; gap:10px;">
#     <img src="https://img.shields.io/badge/License-Apache%202.0-blue.svg" alt="Apache 2.0 licence badge">
#     <span style="font-size:14px; line-height:1.6;">
#       The notebook code is distributed under the Apache License 2.0.
#     </span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     max-width:1100px;
#     margin:0 auto 25px;
#     font-family:Arial, Helvetica, sans-serif;
#     display:grid;
#     grid-template-columns:repeat(auto-fit,minmax(300px,1fr));
#     gap:14px;
# ">
#   <div style="
#       padding:19px;
#       color:#334155;
#       background-color:#ffffff;
#       border:1px solid #dbeafe;
#       border-top:4px solid #2563eb;
#       border-radius:9px;
#       box-shadow:0 3px 10px rgba(15,23,42,0.05);
#   ">
#     <h3 style="margin:0 0 8px; color:#1e40af; font-size:18px;">
#       Sandbox documentation
#     </h3>
#     <p style="margin:0; font-size:14px; line-height:1.65;">
#       For guidance on using the Sandbox and integrating Git for version control,
#       visit the
#       <a href="https://docs.digitalearthafrica.org/en/latest/sandbox"
#          target="_blank"
#          style="color:#1d4ed8; font-weight:700;">
#         Digital Earth Africa documentation
#       </a>.
#     </p>
#   </div>
#
#   <div style="
#       padding:19px;
#       color:#334155;
#       background-color:#ffffff;
#       border:1px solid #d1fae5;
#       border-top:4px solid #059669;
#       border-radius:9px;
#       box-shadow:0 3px 10px rgba(15,23,42,0.05);
#   ">
#     <h3 style="margin:0 0 8px; color:#065f46; font-size:18px;">
#       Available datasets
#     </h3>
#     <p style="margin:0; font-size:14px; line-height:1.65;">
#       Explore products in the Sandbox <strong>Datasets</strong> folder or use the
#       <a href="https://explorer.digitalearth.africa/products"
#          target="_blank"
#          style="color:#047857; font-weight:700;">
#         Digital Earth Africa Metadata Explorer
#       </a>.
#     </p>
#   </div>
# </div>
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>

# %% [markdown]
# <div id="support" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:34px auto 14px;
#     padding:20px 22px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #bae6fd;
#     border-left:6px solid #0284c7;
#     border-radius:10px;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);
# ">
#   <div style="color:#0284c7; font-size:12px; font-weight:700; letter-spacing:1.2px; text-transform:uppercase;">
#     Get help
#   </div>
#   <h2 style="margin:5px 0 7px; color:#0b1026; font-size:25px;">Support</h2>
#   <p style="margin:0; color:#64748b; font-size:14px; line-height:1.65;">
#     Access user guidance, training material, and Helpdesk information.
#   </p>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 18px;
#     padding:22px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#ffffff;
#     background:linear-gradient(135deg,#075985 0%,#0369a1 58%,#0f766e 100%);
#     border-radius:11px;
#     box-shadow:0 5px 16px rgba(15,23,42,0.12);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="max-width:690px;">
#       <h3 style="margin:0; color:#ffffff; font-size:21px;">Need guidance?</h3>
#       <p style="margin:7px 0 0; color:#e0f2fe; font-size:14px; line-height:1.65;">
#         Visit the Training and Help page for guidance on using the Helpdesk,
#         accessing training resources, and consulting the user guide.
#       </p>
#     </div>
#     <a href="https://www.digitalearthafrica.org/platform-resources/training-and-help"
#        target="_blank"
#        style="
#            display:inline-block;
#            padding:10px 15px;
#            color:#075985;
#            background-color:#fef08a;
#            border-radius:7px;
#            font-size:13px;
#            font-weight:700;
#            text-decoration:none;
#        ">Open Training and Help ↗</a>
#   </div>
# </div>
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>

# %% [markdown]
# <div style="
#     max-width:1100px;
#     margin:20px auto 36px;
#     padding:13px 16px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#64748b;
#     background-color:#f8fafc;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     text-align:center;
#     font-size:12px;
# ">
#   <strong>Content date modified:</strong> 21 January 2025
#   &nbsp;•&nbsp;
#   Digital Earth Africa thematic notebook directory
# </div>
