# %% [markdown]
# <img align="centre" src="Supplementary_data/Github_banner.jpg" width="100%">

# %% [markdown]
# <h1 style="color: white; padding: 10px; background-color: #00003f; text-shadow: 1px 1px 1px red;">Digital Earth Africa Services and Tools Thematic Categorisation</h1>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white; background-color: #006400; padding: 10px; margin-left:10%;margin-right:10%; text-shadow: 1px 1px 1px red;">Agriculture and Vegetation</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em;">
#   <tr>
#     <td style=""><a href="../Real_world_examples/Crop_health.ipynb"> Crop health </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Real_world_examples/Crop_health_EVI.ipynb"> Crop Health EVI </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Real_world_examples/Forecasting_vegetation_condition.ipynb"> Forecasting Vegetation Condition</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Cropland_extent.ipynb"> Cropland Extent </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Fractional_Cover.ipynb"> Fractional Cover </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Forest_monitoring.ipynb"> Forest Monitoring </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Mangrove_analysis.ipynb"> Mangrove Analysis</a></td>
#   </tr>
#         <tr>
#     <td style=""><a href="../Real_world_examples/NDVI_animations.ipynb"> NDVI Animations</a></td>
#   </tr>
#         <tr>
#     <td style=""><a href="../Real_world_examples/Phenology_optical.ipynb"> Phenology Optical</a></td>
#   </tr>
#      </tr>
#         <tr>
#     <td style=""><a href="../Real_world_examples/Phenology_radar.ipynb"> Phenology Radar</a></td>
#   </tr>
#      </tr>
#         <tr>
#     <td style=""><a href="../Real_world_examples/Vegetation_anomalies_monthly.ipynb"> Vegetation Anomalies Monthly</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Vegetation_change_detection.ipynb"> Vegetation Change Detection</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Lake_baringo_grazing/Vegetation_phenology_1D.ipynb"> Vegetation Phenology 1D </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Lake_baringo_grazing/Vegetation_phenology_perpixel.ipynb"> Vegetation Phenology Perpixel</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../SDGs/Mountain_Green_Cover_Index/MGCI.ipynb"> MGCI </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/NDVI_Anomaly.ipynb"> NDVI_Anomaly.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/NDVI_Climatology.ipynb"> NDVI_Climatology.ipynb </a></td>
#   </tr>
#      <tr>
#     <td style=""><a href="../Datasets/Global_Mangrove_Watch.ipynb"> Global_Mangrove_Watch.ipynb </a></td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #009fe1; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Coastal</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em;">
#   <tr>
#     <td style=""><a href="../Real_world_examples/Coastal_erosion.ipynb"> Coastal Erosion </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Real_world_examples/Floating_marine_debris.ipynb"> Floating Marine Debris </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Real_world_examples/Intertidal_elevation.ipynb"> Intertidal Elevation</a></td>
#   </tr>
#      <tr>
#     <td style=""><a href="../Real_world_examples/Intertidal_elevation_S2.ipynb"> Intertidal elevation S2</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Coastlines.ipynb"> Coastlines </a></td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #bc8f8f; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Elevation and topography</h1>
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Datasets/Digital_Elevation_Models.ipynb"> Digital Elevation Models </a></td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #bdb76b; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Land Cover</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Burnt_area_mapping.ipynb"> Burnt Area Mapping </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Burnt_area_mapping_near_realtime.ipynb"> Burnt Area Mapping Near Realtime </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Machine_learning_with_ODC.ipynb"> Machine Learning With ODC.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Use_cases/Surface_mining_screening/Surface_mining_screening.ipynb"> Surface Mining Screening </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Land_Use_Land_Cover_Maps.ipynb"> Land Use Land Cover Maps</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #98777b; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Machine Learning</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Scalable_machine_learning/1_Extract_training_data.ipynb"> Extract Training Data </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Scalable_machine_learning/2_Inspect_training_data.ipynb"> Inspect Training Data </a></td>
#   </tr>
#      <tr>
#     <td style=""><a href="../Real_world_examples/Scalable_machine_learning/3_Evaluate_optimize_fit_classifier.ipynb"> Evaluate Optimize Fit Classifier </a></td>
#   </tr>
#        <tr>
#     <td style=""><a href="../Real_world_examples/Scalable_machine_learning/4_Classify_satellite_data.ipynb"> Classify Satellite Data </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Real_world_examples/Scalable_machine_learning/5_Object-based_filtering.ipynb"> Object-based Filtering </a></td>
#   </tr>
#
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #00bfff; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Meteorology</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Animation_with_rainfall.ipynb"> Animation with Rainfall </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb"> Rainfall anomaly CHIRPS </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Temperature_trends.ipynb"> Temperature trends </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Climate_Data_ERA5_AWS.ipynb"> Climate Data ERA5 AWS </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Rainfall_CHIRPS.ipynb"> Rainfall CHIRPS</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #8b008b; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Radar backscatter</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Radar_urban_area_mapping.ipynb"> Radar Urban Area Mapping </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Radar_water_detection.ipynb"> Radar Water Detection </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Ship_detection_with_radar.ipynb"> Ship Detection With Radar </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Sentinel_1.ipynb"> Sentinel 1 </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/ALOS_PALSAR_Annual_Mosaic.ipynb"> ALOS PALSAR Annual Mosaic</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #a9a9a9; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Satellite Images</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Datasets/GeoMAD.ipynb"> GeoMAD </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Rolling_GeoMAD.ipynb"> Rolling GeoMAD </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Landsat_Surface_Reflectance.ipynb"> Landsat Surface Reflectance </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Landsat_Surface_Temperature.ipynb"> Landsat Surface Temperature </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Sentinel_2.ipynb"> Sentinel 2</a></td>
#     </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Planet_basemap.ipynb"> Planet Basemap</a></td>
#     </tr>
#     <tr>
#     <td style=""><a href="../Datasets/OpenStreetMap.ipynb"> Open Street Map</a></td>
#     </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Exporting_satellite_images.ipynb"> Exporting Satellite Images</a></td>
#     </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Generating_satellite_animations.ipynb"> Generating Satellite Animations.ipynb</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #f08080; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Soil</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Datasets/Soil_Moisture.ipynb"> Soil Moisture </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/iSDAsoil.ipynb"> iSDAsoil </a></td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #6495ed; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Surface Water</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Chlorophyll_monitoring.ipynb"> Chlorophyll_monitoring.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Water_extent_WOfS.ipynb"> Water_extent_WOfS.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Water_extent_sentinel_2.ipynb"> Water_extent_sentinel_2.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Water_quality_suspended_matter.ipynb"> Water_quality_suspended_matter.ipynb</a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Wetland_turbidity.ipynb"> Wetland_turbidity.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Wetlands_insight_tool.ipynb"> Wetlands_insight_tool.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Lake_baringo_grazing/Water_Observations_from_Space.ipynb"> Water Observations from Space </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Lake_baringo_grazing/Water_extent.ipynb"> Water_extent.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Monitoring_water_extent/Monitoring_water_extent_WOfS.ipynb"> Monitoring_water_extent_WOfS.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Monitoring_water_extent/Monitoring_water_extent_radar.ipynb"> Monitoring_water_extent_radar.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/0_Wetland_inundation_and_vegetation_dynamics.ipynb"> 0_Wetland_inundation_and_vegetation_dynamics.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/1_Water_extent_longterm_WOfS.ipynb">1_Water_extent_longterm_WOfS.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/2_Water_extent_seasonal_MNDWI.ipynb"> 2_Water_extent_seasonal_MNDWI.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/3_Historical_rainfall.ipynb"> 3_Historical_rainfall.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/4_Visualising_rainfall_discharge_water_extent.ipynb"> 4_Visualising_rainfall_discharge_water_extent.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/5_Rainfall_discharge_modelling.ipynb"> 5_Rainfall_discharge_modelling.ipynb </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Usecases/Okavango/6_Forecasting_water_extent.ipynb"> 6_Forecasting_water_extent.ipynb </a></td>
#   </tr>
#      <tr>
#     <td style=""><a href="../Usecases/surface_water_count/Vectorise_waterbodies.ipynb"> Vectorise waterbodies </a></td>
#   </tr>
#   <tr>
#     <td style=""><a href="../Datasets/Water_Observations_from_Space.ipynb"> Water Observations from Space </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/Waterbodies.ipynb"> Waterbodies </a></td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="border:1px solid Green;color: white;  background-color: #b8860b; padding: 10px; text-shadow: 1px 1px 1px red;margin-left:10%;margin-right:10%;">Urban</h1>
#
# <table style="width:80%; font-weight: bold;font-size: 1.2em">
#     <tr>
#     <td style=""><a href="../Real_world_examples/Urban_change_detection.ipynb"> Urban change detection </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Real_world_examples/Urban_index_comparison.ipynb"> Urban Index Comparison </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/High_Resolution_Population_Density.ipynb"> High Resolution Population Density </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/World_Settlement_Footprint-Evolution.ipynb"> World Settlement Footprint-Evolution </a></td>
#   </tr>
#     <tr>
#     <td style=""><a href="../Datasets/World_Settlement_Footprint.ipynb"> World Settlement Footprint </a></td>
#   </tr>
# </table>

# %% [markdown]
# ---------------------------------
# <img align="left" src="https://img.shields.io/badge/License-Apache%202.0-blue.svg">.

# %% [markdown]
# For guidance on the Sandbox and integrating Git for version control, please see the [Digital Earth Africa documentation](https://docs.digitalearthafrica.org/en/latest/sandbox).
#
# <span style="color:#485461"><b>Datasets</b></span>
#
# The Sandbox enables access to Digital Earth Africa's datasets which can be explored in the Datasets folder. The list of datasets can also be found in the [metadata explorer](https://explorer.digitalearth.africa/products).

# %% [markdown]
#  <div class="alert alert-block alert-info"><b><h2> Support</h2> </b></div>

# %% [markdown]
# The [Training and Help](https://www.digitalearthafrica.org/platform-resources/training-and-help) page can be consulted for guidance on using the Helpdesk and accessing training and the user guide.

# %% [markdown]
# **Date modified: 15 January 2025**
