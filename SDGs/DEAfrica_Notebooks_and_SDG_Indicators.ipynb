# %% [markdown]
# <div id="page-top" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:18px auto 0;
#     font-family:Arial, Helvetica, sans-serif;
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:20px;
#       padding:22px 26px;
#       background-color:#ffffff;
#       border:1px solid #e2e8f0;
#       border-radius:14px 14px 0 0;
#   ">
#     <img
#         src="../Supplementary_data/DE_Africa_Logo_Stacked_RGB_small.jpg"
#         alt="Digital Earth Africa"
#         style="display:block; max-width:200px; width:42%; height:auto;"
#     >
#     <img
#         src="../Supplementary_data/SDG_icons/E_SDG_logo_without_UN_emblem_Square_Transparent_WEB.png"
#         alt="Sustainable Development Goals"
#         style="display:block; width:115px; height:auto;"
#     >
#   </div>
#
#   <div style="
#       padding:25px 28px;
#       color:#ffffff;
#       background:linear-gradient(135deg,#0b1026 0%,#172554 58%,#0f766e 100%);
#       border-radius:0 0 14px 14px;
#       box-shadow:0 5px 18px rgba(15,23,42,0.15);
#   ">
#     <div style="
#         color:#fcd34d;
#         font-size:12px;
#         font-weight:700;
#         letter-spacing:1.4px;
#         text-transform:uppercase;
#     ">Earth observation for sustainable development</div>
#     <h1 style="
#         margin:6px 0 8px;
#         color:#ffffff;
#         font-size:31px;
#         font-weight:750;
#         line-height:1.25;
#     ">DE Africa Services and Tools for the SDGs</h1>
#     <p style="
#         max-width:840px;
#         margin:0;
#         color:#e2e8f0;
#         font-size:15px;
#         line-height:1.65;
#     ">
#       Explore Digital Earth Africa datasets, services, and Jupyter notebooks
#       that can support monitoring and reporting for selected Sustainable
#       Development Goal indicators.
#     </p>
#     <div style="display:flex; flex-wrap:wrap; gap:9px; margin-top:18px;">
#       <a href="../DEAfricaLandingPage.ipynb" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#0b1026;
#           background-color:#fcd34d;
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">← Landing Page</a>
#       <a href="#goal-navigation" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:rgba(255,255,255,0.13);
#           border:1px solid rgba(255,255,255,0.25);
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Browse SDGs</a>
#       <a href="../DEAfricaThematic.ipynb" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:rgba(255,255,255,0.13);
#           border:1px solid rgba(255,255,255,0.25);
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Thematic Tools</a>
#       <a href="../DEAfricaInfo.ipynb" style="
#           display:inline-block;
#           padding:9px 14px;
#           color:#ffffff;
#           background-color:#2563eb;
#           border-radius:7px;
#           font-size:13px;
#           font-weight:700;
#           text-decoration:none;
#       ">Tech Alerts</a>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div id="goal-navigation" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:16px auto 26px;
#     padding:16px 18px;
#     font-family:Arial, Helvetica, sans-serif;
#     background-color:#ffffff;
#     border:1px solid #dbe2ea;
#     border-radius:10px;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:center;
#       gap:8px;
#   ">
#     <span style="
#         margin-right:4px;
#         color:#64748b;
#         font-size:12px;
#         font-weight:700;
#         letter-spacing:0.8px;
#         text-transform:uppercase;
#     ">Browse SDGs</span>
#
# <a href="#goal-2" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#DDA63A;
#     background-color:#FFF8E7;
#     border:1px solid #F2D79A;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 2</a>
#
# <a href="#goal-6" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#26BDE2;
#     background-color:#EFFBFE;
#     border:1px solid #A9E7F4;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 6</a>
#
# <a href="#goal-9" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#FD6925;
#     background-color:#FFF4EE;
#     border:1px solid #FDC2A7;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 9</a>
#
# <a href="#goal-11" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#FD9D24;
#     background-color:#FFF8EB;
#     border:1px solid #FFD69E;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 11</a>
#
# <a href="#goal-13" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#3F7E44;
#     background-color:#F1F8F2;
#     border:1px solid #B8D8BB;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 13</a>
#
# <a href="#goal-14" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#0A97D9;
#     background-color:#EFF9FE;
#     border:1px solid #A9DCF3;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 14</a>
#
# <a href="#goal-15" style="
#     display:inline-block;
#     padding:8px 12px;
#     color:#56C02B;
#     background-color:#F3FCEB;
#     border:1px solid #BEE8A9;
#     border-radius:999px;
#     font-size:13px;
#     font-weight:700;
#     text-decoration:none;
# ">Goal 15</a>
#
#   </div>
#
#   <p style="
#       margin:12px 0 0;
#       color:#64748b;
#       font-size:13px;
#       line-height:1.55;
#       text-align:center;
#   ">
#     Select a goal to jump directly to its indicators and related notebooks.
#   </p>
# </div>

# %% [markdown]
# <div id="background" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 14px;
#     padding:20px 22px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:6px solid #0f766e;
#     border-radius:10px;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);
# ">
#   <div style="
#       color:#0f766e;
#       font-size:12px;
#       font-weight:700;
#       letter-spacing:1.2px;
#       text-transform:uppercase;
#   ">Overview</div>
#
#   <h2 style="
#       margin:5px 0 7px;
#       color:#0b1026;
#       font-size:26px;
#       line-height:1.3;
#   ">How Earth Observation Supports the SDGs</h2>
#
#   <p style="
#       margin:0;
#       color:#64748b;
#       font-size:15px;
#       line-height:1.65;
#   ">
#     Digital Earth Africa provides consistent satellite observations and
#     analytical tools that can complement national data and strengthen
#     evidence-based monitoring.
#   </p>
# </div>

# %% [markdown]
# <div style="
#     max-width:1100px;
#     margin:0 auto 12px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#0b1026;
#     font-size:20px;
#     font-weight:700;
# ">
#   Background
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 12px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:4px solid #2563eb;
#     border-radius:8px;
#     font-size:15px;
#     line-height:1.7;
#     box-shadow:0 2px 8px rgba(15,23,42,0.04);
# ">
#   <div style="
#       margin-bottom:7px;
#       color:#2563eb;
#       font-size:16px;
#       font-weight:700;
#   ">A global framework for measurable progress</div>
#   <p style="margin:0;">The Sustainable Development Goals represent a data-driven, evidence-based approach to sustainable development <a href="http://www.eohandbook.com/sdg/files/CEOS_EOHB_2018_SDG.pdf" target="_blank" style="color:#1d4ed8; font-weight:700;">(The CEOS Earth Observation Handbook Special 2018 Edition)</a>. The aim of the Sustainable Development Goals (SDG) framework is to end poverty, improve health and education, reduce inequality, design sustainable cities, support economic growth, tackle climate change and leave no one behind <a href="https://doi.org/10.3390/su14031191" target="_blank" style="color:#1d4ed8; font-weight:700;">(Andries et al. 2022)</a>. The purpose of the Global Indicator Framework is to provide means by which to measure, monitor and report progress made in the implementation of the SDGs and their respective targets, for the follow up and review of the 2030 Agenda for Sustainable Development. The Global Indicator Framework is designed around 232 SDG Indicators.</p>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 12px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:4px solid #7c3aed;
#     border-radius:8px;
#     font-size:15px;
#     line-height:1.7;
#     box-shadow:0 2px 8px rgba(15,23,42,0.04);
# ">
#   <div style="
#       margin-bottom:7px;
#       color:#7c3aed;
#       font-size:16px;
#       font-weight:700;
#   ">Why Earth Observation matters</div>
#   <p style="margin:0;">Earth Observation data is an essential tool in the development of the information required by many of the SDG Indicators given its cost-effectiveness pertaining to data acquisition on all scales and information richness. <a href="http://www.eohandbook.com/sdg/files/CEOS_EOHB_2018_SDG.pdf" target="_blank" style="color:#1d4ed8; font-weight:700;">(The CEOS Earth Observation Handbook Special 2018 Edition)</a>, <a href="https://doi.org/10.1186/s12302-020-00397-4" target="_blank" style="color:#1d4ed8; font-weight:700;">(Ferreira, B., Iten, M. &amp; Silva, R.G. 2020)</a>.</p>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 12px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:4px solid #0f766e;
#     border-radius:8px;
#     font-size:15px;
#     line-height:1.7;
#     box-shadow:0 2px 8px rgba(15,23,42,0.04);
# ">
#   <div style="
#       margin-bottom:7px;
#       color:#0f766e;
#       font-size:16px;
#       font-weight:700;
#   ">Digital Earth Africa's contribution</div>
#   <p style="margin:0;">Digital Earth Africa (DE Africa) hosts data, services and Jupyter Notebooks that can be used to address real world problems and contribute to the Global Indicator Framework.</p>
# </div>

# %% [markdown]
# <div id="indicators" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:34px auto 16px;
#     padding:20px 22px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background-color:#f8fafc;
#     border:1px solid #cbd5e1;
#     border-left:6px solid #2563eb;
#     border-radius:10px;
# ">
#   <div style="
#       color:#2563eb;
#       font-size:12px;
#       font-weight:700;
#       letter-spacing:1.2px;
#       text-transform:uppercase;
#   ">Notebook directory</div>
#
#   <h2 style="
#       margin:5px 0 7px;
#       color:#0b1026;
#       font-size:26px;
#       line-height:1.3;
#   ">SDG Indicators Supported by DE Africa Notebooks</h2>
#
#   <p style="
#       margin:0;
#       color:#64748b;
#       font-size:15px;
#       line-height:1.65;
#   ">
#     The links below show how DE Africa datasets, services, and analytical
#     workflows can contribute to selected Sustainable Development Goal indicators.
#   </p>
# </div>

# %% [markdown]
# <div id="goal-2" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#FFF8E7 0%,#ffffff 100%);
#     border:1px solid #F2D79A;
#     border-top:6px solid #DDA63A;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-02.png"
#           alt="SDG Goal 2"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#DDA63A;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 2</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Zero Hunger</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">End hunger, achieve food security and improved nutrition, and promote sustainable agriculture.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#DDA63A;
#         background-color:#ffffff;
#         border:1px solid #F2D79A;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">2 indicators</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #F2D79A;
#     border-left:5px solid #DDA63A;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#DDA63A;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 2.4.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of agricultural area under productive and sustainable agriculture</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#DDA63A;
#         background-color:#FFF8E7;
#         border:1px solid #F2D79A;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">13 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Soil_Moisture.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Global Root-zone moisture Analysis &amp; Forecasting System (GRAFS)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/NDVI_Climatology.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Climatology</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Rainfall_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall estimates (CHIRPS)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Cropland_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Cropland extent maps for Africa</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification datasets</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Change_filmstrips.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring change through time using satellite imagery filmstrip plots</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Crop_health.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Measuring crop health</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Forecasting_vegetation_condition.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forecasting cropland vegetation condition</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Irrigated_cropping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Identifying active irrigated cropping</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Phenology_optical.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology (Optical)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Phenology_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology (Radar)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_anomalies_monthly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monthly vegetation condition anomalies</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Scalable_machine_learning/0_README.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Scalable Supervised Machine Learning on the Open Data Cube ReadME</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #F2D79A;
#     border-left:5px solid #DDA63A;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#DDA63A;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 2.c.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Indicator of food price anomalies</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#DDA63A;
#         background-color:#FFF8E7;
#         border:1px solid #F2D79A;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">9 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Soil_Moisture.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Global Root-zone moisture Analysis &amp; Forecasting System (GRAFS)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/NDVI_Climatology.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Climatology</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Rainfall_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall estimates (CHIRPS)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Crop_health.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Measuring crop health</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Forecasting_vegetation_condition.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forecasting cropland vegetation condition</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Phenology_optical.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology (Optical)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Phenology_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Phenology (Radar)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_anomalies_monthly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monthly vegetation condition anomalies</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall anomalies from Climate Hazards Group InfraRed Precipitation with Station data (CHIRPS)</span>
#   <span style="color:#DDA63A; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-6" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#EFFBFE 0%,#ffffff 100%);
#     border:1px solid #A9E7F4;
#     border-top:6px solid #26BDE2;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-06.png"
#           alt="SDG Goal 6"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#26BDE2;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 6</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Clean Water and Sanitation</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Ensure availability and sustainable management of water and sanitation for all.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#26BDE2;
#         background-color:#ffffff;
#         border:1px solid #A9E7F4;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">4 indicators</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9E7F4;
#     border-left:5px solid #26BDE2;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#26BDE2;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 6.3.2</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of bodies of water with good ambient water quality</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#26BDE2;
#         background-color:#EFFBFE;
#         border:1px solid #A9E7F4;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">2 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Frequently_used_code/Monitoring_water_quality.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Water Quality</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Chlorophyll_monitoring.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring chlorophyll-a in African waterbodies</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9E7F4;
#     border-left:5px solid #26BDE2;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#26BDE2;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 6.4.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Change in water use efficiency over time</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#26BDE2;
#         background-color:#EFFBFE;
#         border:1px solid #A9E7F4;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">2 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/WaPOR.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>WaPOR data</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Inspecting_WaPOR_through_time.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Inspecting WaPOR data through time</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9E7F4;
#     border-left:5px solid #26BDE2;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#26BDE2;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 6.4.2</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Level of water stress: freshwater withdrawal as a proportion of available freshwater resources</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#26BDE2;
#         background-color:#EFFBFE;
#         border:1px solid #A9E7F4;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">6 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Climate_Data_ERA5_AWS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>ERA5 climate data</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Cropland_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Cropland extent maps for Africa</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Irrigated_cropping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Identifying active irrigated cropping</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall anomalies from Climate Hazards Group InfraRed Precipitation with Station data (CHIRPS)</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Water_extent_sentinel_2.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Determining seasonal extent of waterbodies with Sentinel-2</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Water_extent_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping longer-term changes in water extent with WOfS</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9E7F4;
#     border-left:5px solid #26BDE2;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#26BDE2;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 6.6.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Change in the extent of water-related ecosystems over time</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#26BDE2;
#         background-color:#EFFBFE;
#         border:1px solid #A9E7F4;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">20 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Climate_Data_ERA5_AWS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>ERA5 climate data</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Rainfall_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall estimates (CHIRPS)</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Water_Observations_from_Space.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water Observations from Space</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Frequently_used_code/Contour_extraction.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Extracting contour lines</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Change_filmstrips.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring change through time using satellite imagery filmstrip plots</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Radar_water_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Water detection with Sentinel-1</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall anomalies from Climate Hazards Group InfraRed Precipitation with Station data (CHIRPS)</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Wetlands_insight_tool.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Wetlands Insight Tool</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Water_extent_sentinel_2.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Determining seasonal extent of waterbodies with Sentinel-2</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Water_extent_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping longer-term changes in water extent with WOfS</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Okavango use case</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Use_cases/Okavango/0_Wetland_inundation_and_vegetation_dynamics.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring wetlands in the Okavango</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/1_Water_extent_longterm_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping long-term changes in the annual water extent of the Okavango Delta</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/2_Water_extent_seasonal_MNDWI.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping the seasonal changes to the open water extent of the Okavango delta</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/3_Historical_rainfall.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Extracting historical climate (rainfall) data over selected basins</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/4_Visualising_rainfall_discharge_water_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Visualising the correlation between rainfall, surface water extent, and discharge</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/5_Rainfall_discharge_modelling.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Modelling discharge at Mohembo using uppercatchment rainfall</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Okavango/6_Forecasting_water_extent.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Forecasting surface water extent in the Okavango delta</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Monitoring water extent use case</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Use_cases/Monitoring_water_extent/Monitoring_water_extent_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping water extent and rainfall using Sentinel-1 and CHIRPS</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Monitoring_water_extent/Monitoring_water_extent_WOfS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mapping water extent and rainfall using WOfS and CHIRPS</span>
#   <span style="color:#26BDE2; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-9" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#FFF4EE 0%,#ffffff 100%);
#     border:1px solid #FDC2A7;
#     border-top:6px solid #FD6925;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-09.png"
#           alt="SDG Goal 9"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#FD6925;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 9</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Industry, Innovation and Infrastructure</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Build resilient infrastructure, promote inclusive and sustainable industrialisation, and foster innovation.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#FD6925;
#         background-color:#ffffff;
#         border:1px solid #FDC2A7;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">1 indicator</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #FDC2A7;
#     border-left:5px solid #FD6925;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#FD6925;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 9.1.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of the rural population who live within 2 km of an all-season</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#FD6925;
#         background-color:#FFF4EE;
#         border:1px solid #FDC2A7;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">5 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#FD6925; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine learning with the Open Data Cube</span>
#   <span style="color:#FD6925; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Radar_urban_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban area mapping using Sentinel 1 data</span>
#   <span style="color:#FD6925; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_index_comparison.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urbanization Index Comparisons with Global Human Settlement (GHS)</span>
#   <span style="color:#FD6925; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Detecting change in urban extent</span>
#   <span style="color:#FD6925; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-11" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#FFF8EB 0%,#ffffff 100%);
#     border:1px solid #FFD69E;
#     border-top:6px solid #FD9D24;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-11.png"
#           alt="SDG Goal 11"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#FD9D24;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 11</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Sustainable Cities and Communities</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Make cities and human settlements inclusive, safe, resilient, and sustainable.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#FD9D24;
#         background-color:#ffffff;
#         border:1px solid #FFD69E;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">3 indicators</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #FFD69E;
#     border-left:5px solid #FD9D24;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#FD9D24;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 11.1.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of urban population living in slums, informal settlements or inadequate housing</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#FD9D24;
#         background-color:#FFF8EB;
#         border:1px solid #FFD69E;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">5 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine learning with the Open Data Cube</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Radar_urban_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban area mapping using Sentinel 1 data</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_index_comparison.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urbanization Index Comparisons with Global Human Settlement (GHS)</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Detecting change in urban extent</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #FFD69E;
#     border-left:5px solid #FD9D24;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#FD9D24;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 11.3.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Ratio of land consumption rate to population growth rate</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#FD9D24;
#         background-color:#FFF8EB;
#         border:1px solid #FFD69E;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">3 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Real_world_examples/Change_filmstrips.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring change through time using satellite imagery filmstrip plots</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine learning with the Open Data Cube</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Radar_urban_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban area mapping using Sentinel 1 data</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #FFD69E;
#     border-left:5px solid #FD9D24;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#FD9D24;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 11.7.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Average share of the built-up area of cities that is open space for public use for all, by sex, age and persons with disabilities</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#FD9D24;
#         background-color:#FFF8EB;
#         border:1px solid #FFD69E;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">5 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Real_world_examples/Change_filmstrips.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring change through time using satellite imagery filmstrip plots</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Machine_learning_with_ODC.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Machine learning with the Open Data Cube</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_index_comparison.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urbanization Index Comparisons with Global Human Settlement (GHS)</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Urban_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Detecting change in urban extent</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Radar_urban_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Urban area mapping using Sentinel 1 data</span>
#   <span style="color:#FD9D24; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-13" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#F1F8F2 0%,#ffffff 100%);
#     border:1px solid #B8D8BB;
#     border-top:6px solid #3F7E44;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-13.png"
#           alt="SDG Goal 13"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#3F7E44;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 13</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Climate Action</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Take urgent action to combat climate change and its impacts.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#3F7E44;
#         background-color:#ffffff;
#         border:1px solid #B8D8BB;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">1 indicator</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #B8D8BB;
#     border-left:5px solid #3F7E44;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#3F7E44;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 13.1.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Number of deaths, missing persons and directly affected persons attributed to disasters per 100,000 population</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#3F7E44;
#         background-color:#F1F8F2;
#         border:1px solid #B8D8BB;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">6 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Digital_Elevation_Models.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Digital Elevation Models</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Burnt_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Burnt Area Mapping</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Rainfall_anomaly_CHIRPS.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Rainfall anomalies from Climate Hazards Group InfraRed Precipitation with Station data (CHIRPS)</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Ship_detection_with_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Identifying ships with Sentinel-1</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Coastal_erosion.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring coastal erosion along Africa&#x27;s coastline</span>
#   <span style="color:#3F7E44; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-14" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#EFF9FE 0%,#ffffff 100%);
#     border:1px solid #A9DCF3;
#     border-top:6px solid #0A97D9;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-14.png"
#           alt="SDG Goal 14"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#0A97D9;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 14</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Life Below Water</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Conserve and sustainably use oceans, seas, and marine resources for sustainable development.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#0A97D9;
#         background-color:#ffffff;
#         border:1px solid #A9DCF3;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">2 indicators</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9DCF3;
#     border-left:5px solid #0A97D9;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#0A97D9;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 14.1.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">(a) Index of coastal eutrophication; and (b) plastic debris density</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#0A97D9;
#         background-color:#EFF9FE;
#         border:1px solid #A9DCF3;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">1 resource</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Real_world_examples/Chlorophyll_monitoring.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring chlorophyll-a in African waterbodies</span>
#   <span style="color:#0A97D9; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #A9DCF3;
#     border-left:5px solid #0A97D9;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#0A97D9;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 14.5.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Coverage of protected areas in relation to marine areas</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#0A97D9;
#         background-color:#EFF9FE;
#         border:1px solid #A9DCF3;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">3 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#0A97D9; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Mangrove_analysis.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Mangrove Extents</span>
#   <span style="color:#0A97D9; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Ship_detection_with_radar.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Identifying ships with Sentinel-1</span>
#   <span style="color:#0A97D9; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div id="goal-15" style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:30px auto 13px;
#     padding:18px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#1f2937;
#     background:linear-gradient(180deg,#F3FCEB 0%,#ffffff 100%);
#     border:1px solid #BEE8A9;
#     border-top:6px solid #56C02B;
#     border-radius:11px;
#     box-shadow:0 4px 13px rgba(15,23,42,0.06);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:center;
#       justify-content:space-between;
#       gap:16px;
#   ">
#     <div style="display:flex; align-items:center; gap:15px;">
#       <img
#           src="../Supplementary_data/SDG_icons/E_Inverted_Icons_WEB-15.png"
#           alt="SDG Goal 15"
#           style="display:block; width:82px; height:82px; object-fit:contain;"
#       >
#       <div>
#         <div style="
#             color:#56C02B;
#             font-size:12px;
#             font-weight:700;
#             letter-spacing:1px;
#             text-transform:uppercase;
#         ">Sustainable Development Goal 15</div>
#         <h2 style="
#             margin:4px 0 5px;
#             color:#0b1026;
#             font-size:23px;
#             line-height:1.3;
#         ">Life on Land</h2>
#         <p style="
#             max-width:760px;
#             margin:0;
#             color:#64748b;
#             font-size:14px;
#             line-height:1.6;
#         ">Protect and restore terrestrial ecosystems, manage forests sustainably, combat desertification, and reverse land degradation and biodiversity loss.</p>
#       </div>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:6px 11px;
#         color:#56C02B;
#         background-color:#ffffff;
#         border:1px solid #BEE8A9;
#         border-radius:999px;
#         font-size:12px;
#         font-weight:700;
#     ">4 indicators</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #BEE8A9;
#     border-left:5px solid #56C02B;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#56C02B;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 15.1.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Forest area as a proportion of total land area</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#56C02B;
#         background-color:#F3FCEB;
#         border:1px solid #BEE8A9;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">4 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Global_Mangrove_Watch.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Global Mangrove Watch</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Fractional_Cover.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Fractional Cover</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Mangrove_analysis.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Mangrove Extents</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #BEE8A9;
#     border-left:5px solid #56C02B;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#56C02B;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 15.1.2</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of important sites for terrestrial and freshwater biodiversity that are covered by protected areas, by ecosystem type</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#56C02B;
#         background-color:#F3FCEB;
#         border:1px solid #BEE8A9;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">5 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Global_Mangrove_Watch.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Global Mangrove Watch</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Mangrove_analysis.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring Mangrove Extents</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Lake Baringo use case</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Use_cases/Lake_baringo_grazing/Vegetation_phenology_1D.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation phenology in the Ruko Conservancy</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Lake_baringo_grazing/Vegetation_phenology_perpixel.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Per-pixel vegetation phenology in the Ruko Conservancy</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #BEE8A9;
#     border-left:5px solid #56C02B;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#56C02B;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 15.3.1</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Proportion of land that is degraded over total land area</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#56C02B;
#         background-color:#F3FCEB;
#         border:1px solid #BEE8A9;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">9 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="../Datasets/Landcover_Classification.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Land Cover Classification Datasets</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/Fractional_Cover.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Fractional Cover</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Datasets/NDVI_Climatology.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>NDVI Climatology</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Change_filmstrips.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring change through time using satellite imagery filmstrip plots</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Coastal_erosion.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monitoring coastal erosion along Africa&#x27;s coastline</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Change Detection</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_anomalies_monthly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monthly vegetation condition anomalies</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Use_cases/Surface_mining_screening/Surface_mining_screening.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Surface Mining Screening</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Scalable_machine_learning/0_README.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Scalable Supervised Machine Learning on the Open Data Cube ReadME</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# </div>

# %% [markdown]
# <div style="
#     box-sizing:border-box;
#     max-width:1100px;
#     margin:0 auto 13px;
#     padding:19px 20px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #BEE8A9;
#     border-left:5px solid #56C02B;
#     border-radius:9px;
#     box-shadow:0 2px 9px rgba(15,23,42,0.04);
# ">
#   <div style="
#       display:flex;
#       flex-wrap:wrap;
#       align-items:flex-start;
#       justify-content:space-between;
#       gap:10px;
#   ">
#     <div style="max-width:850px;">
#       <div style="
#           color:#56C02B;
#           font-size:12px;
#           font-weight:700;
#           letter-spacing:0.8px;
#           text-transform:uppercase;
#       ">Indicator 15.4.2</div>
#       <h3 style="
#           margin:5px 0 0;
#           color:#0b1026;
#           font-size:18px;
#           line-height:1.45;
#       ">Mountain Green Cover Index</h3>
#     </div>
#     <span style="
#         display:inline-block;
#         padding:5px 9px;
#         color:#56C02B;
#         background-color:#F3FCEB;
#         border:1px solid #BEE8A9;
#         border-radius:999px;
#         font-size:11px;
#         font-weight:700;
#     ">4 resources</span>
#   </div>
#
#
# <div style="margin-top:14px;">
#   <div style="
#       margin-bottom:8px;
#       color:#64748b;
#       font-size:11px;
#       font-weight:700;
#       letter-spacing:0.8px;
#       text-transform:uppercase;
#   ">Related notebooks</div>
#
#   <div style="
#       display:grid;
#       grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
#       gap:9px;
#   ">
#
# <a href="Mountain_Green_Cover_Index/MGCI.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Mountain Green Cover Index Notebook</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Burnt_area_mapping.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Burnt Area Mapping</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_change_detection.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Vegetation Change Detection</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
# <a href="../Real_world_examples/Vegetation_anomalies_monthly.ipynb" style="
#     box-sizing:border-box;
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:12px;
#     min-height:46px;
#     padding:10px 12px;
#     color:#334155;
#     background-color:#ffffff;
#     border:1px solid #e2e8f0;
#     border-radius:7px;
#     font-size:13px;
#     font-weight:700;
#     line-height:1.4;
#     text-decoration:none;
# ">
#   <span>Monthly vegetation condition anomalies</span>
#   <span style="color:#56C02B; font-size:15px;">→</span>
# </a>
#
#   </div>
# </div>
#
#
# <div style="margin-top:16px; text-align:right;">
#   <a href="#page-top" style="
#       display:inline-block;
#       padding:7px 11px;
#       color:#475569;
#       background-color:#f8fafc;
#       border:1px solid #cbd5e1;
#       border-radius:7px;
#       font-size:12px;
#       font-weight:700;
#       text-decoration:none;
#   ">↑ Back to top</a>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     max-width:1100px;
#     margin:25px auto 38px;
#     padding:16px 18px;
#     font-family:Arial, Helvetica, sans-serif;
#     color:#64748b;
#     background-color:#f8fafc;
#     border:1px solid #e2e8f0;
#     border-radius:8px;
#     text-align:center;
#     font-size:12px;
#     line-height:1.6;
# ">
#   Digital Earth Africa — Earth observation tools for monitoring sustainable development
#   <br>
#   <a href="../DEAfricaLandingPage.ipynb" style="color:#0f766e; font-weight:700;">Return to the Landing Page</a>
# </div>
