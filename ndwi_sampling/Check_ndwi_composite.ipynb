# %%
# %matplotlib inline
import xarray as xr
import glob
import numpy as np

# %%
fs = glob.glob('NDWI_composite/southern_NDWI_tile-*.tif')
fs.sort()

check_fs = []
for f in fs:
    data = xr.open_rasterio(f)
    bad_frac = np.isnan(data).mean().values
    if bad_frac>0: 
        print(f, bad_frac)
        check_fs.append(f)
# Out:
# NDWI_composite/southern_NDWI_tile-110.tif 2.6002601820338144e-07
# NDWI_composite/southern_NDWI_tile-202.tif 9.770395701025892e-06
# NDWI_composite/southern_NDWI_tile-207.tif 5.597760671820845e-07

# %%
data = xr.open_rasterio('NDWI_composite/southern_NDWI_tile-207.tif')
#data = xr.open_rasterio(check_fs[1])

# %%
np.isnan(data).mean().values
# Out:
# array(5.59776067e-07)

# %%
data.squeeze().plot.imshow();
